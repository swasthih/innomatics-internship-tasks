# %% [markdown]
# # Problem 1: Mobile Recharge Validation System

# %%
def validate_recharge():
    valid_plans = [199, 299, 399, 599]
                  
    while True:
        amount = int(input("Enter recharge amount: Rs."))

        if amount < 50:
            print("Recharge amount must be at least Rs.50. Try again.")
        elif amount not in valid_plans:
            print("Invalid plan. Available plans:", valid_plans)
        else:
            print("Recharge Successful!")
            break
validate_recharge()
# Out:
# Enter recharge amount: Rs. 45
# Recharge amount must be at least Rs.50. Try again.
# Enter recharge amount: Rs. 50
# Invalid plan. Available plans: [199, 299, 399, 599]
# Enter recharge amount: Rs. 200
# Invalid plan. Available plans: [199, 299, 399, 599]
# Enter recharge amount: Rs. 199
# Recharge Successful!

# %% [markdown]
# # Problem 2 : Inventory Reorder Alert System

# %%
def check_inventory(products):
    for product, stock in products.items():
        if stock < 15:
            print(f"{product}: Reorder Alert")
        else:
            print(f"{product}: Stock OK")

products = {
    "Rice": 10,
    "Sugar": 25,
    "Oil": 12,
    "Soap": 30
}

check_inventory(products)
# Out:
# Rice: Reorder Alert
# Sugar: Stock OK
# Oil: Reorder Alert
# Soap: Stock OK

# %% [markdown]
# # Problem 3 : Student Result Processing System

# %%
def check_result(marks):
    total = 0

    for mark in marks:
        total += mark
        
    average = total / len(marks)

    print(f"Average Marks: {average}")

    if average >= 50:
        return "Pass"
    else:
        return "Fail"

marks = [60, 45, 70, 55]
print("Result:", check_result(marks))
# Out:
# Average Marks: 57.5
# Result: Pass

# %% [markdown]
# # Problem 4: Cab Fare Estimator with Retry Option

# %%
def calculate_fare(distance, peak):
    base_fare = 50
    per_km = 12

    fare = base_fare + (distance * per_km)

    if peak:
        fare *= 1.25

    return fare

while True:
    distance = float(input("Enter distance (km): "))
    peak_input = input("Is it peak hour? (yes/no): ").lower()

    peak =True if peak_input == "yes" else False

    total_fare = calculate_fare(distance, peak)
    print(f"Total Fare: ₹{total_fare:.2f}")

    retry = input("Do you want to calculate again? (yes/no): ").lower()
    if retry != "yes":
        break
# Out:
# Enter distance (km):  26
# Is it peak hour? (yes/no):  yes
# Total Fare: ₹452.50
# Do you want to calculate again? (yes/no):  yes
# Enter distance (km):  26
# Is it peak hour? (yes/no):  no
# Total Fare: ₹362.00
# Do you want to calculate again? (yes/no):  no

# %% [markdown]
# # Problem 5: Employee Attendance Eligibility Checker

# %%
def check_attendance(attendance):
    present_days = 0

    for day in attendance:
        if day == "P":
            present_days += 1

    percentage = (present_days / len(attendance)) * 100
    print(f"Attendance Percentage: {percentage}%")

    if percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"


# Example
attendance_list = ["P", "A", "P", "P", "A", "P", "P"]
print("Status:", check_attendance(attendance_list))
# Out:
# Attendance Percentage: 71.42857142857143%
# Status: Not Eligible

# %% [markdown]
# # Problem 6: Password Strength Checker

# %%
def check_password(password):
    special_chars = "@#$"

    if len(password) < 8:
        return "Weak Password (Minimum length 8 required)"

    has_digit = False
    has_special = False

    for char in password:
        if char.isdigit():
            has_digit = True
        if char in special_chars:
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    else:
        return "Weak Password (Must contain digit and special character)"


# Example
pwd = input("Enter password: ")
print(check_password(pwd))
